# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/Video_Games_Sales.csv')
data = data[['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher']]

# %% [markdown]
# ### Deal with missing values

# %%
data = data.dropna(subset = ['Name'])

# %%
data = data.fillna(value = '')

# %% [markdown]
# ### Preprocessing

# %%
data[['Name', 'Platform', 'Genre', 'Publisher']] = data[['Name', 'Platform', 'Genre', 'Publisher']].applymap(lambda x: x.lower())

# %%
data = data[ ~ data.duplicated()]

# %%
platform_df = pd.DataFrame(data.groupby('Name')['Platform'].apply(lambda x: "%s" % ' '.join(x)))
genre_df = pd.DataFrame(data.groupby('Name')['Genre'].apply(lambda x: "%s" % ' '.join(x)))
df = pd.merge(platform_df, genre_df, on = 'Name')
df
# Out:
#                                                Platform              Genre
# Name
#  beyblade burst                                     3ds       role-playing
#  fire emblem fates                                  3ds       role-playing
#  frozen: olaf's quest                            3ds ds  platform platform
#  haikyu!! cross team match!                         3ds          adventure
#  tales of xillia 2                                  ps3       role-playing
# ...                                                 ...                ...
# zumba fitness rush                                 x360             sports
# zumba fitness: world party                     xone wii          misc misc
# zwei!!                                              psp       role-playing
# zyuden sentai kyoryuger: game de gaburincho!!       3ds             action
# ¡shin chan flipa en colores!                         ds           platform
#
# [11562 rows x 2 columns]

# %%
df = df.merge(data[['Name', 'Publisher']], on = 'Name', how = 'left')

# %% [markdown]
# Create a column called **meta** merged info from **genre, platform, publisher**.

# %%
df['metadata'] = df[['Publisher', 'Platform', 'Genre']].apply(lambda x: ' '.join(x), axis = 1)

# %% [markdown]
# ## Create a content latent matrix from metadata

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer()
count_matrix = count.fit_transform(df['metadata'])

# %%
columns = count.get_feature_names()

# %%
count_df = pd.DataFrame(count_matrix.toarray(), index = df.Name.tolist(), columns = columns)

# %%
count_df.shape
# Out:
# (16716, 692)

# %% [markdown]
# ### Dimensionality reduction

# %%
from sklearn.decomposition import TruncatedSVD

#Apply SVD
svd = TruncatedSVD(n_components = 50)
latent_df = svd.fit_transform(count_df)

# %%
# Plot variance as a function of the number of components.
plt.plot(svd.explained_variance_ratio_.cumsum())
plt.xlabel('number of singular value components')
plt.ylabel('Cumulative percent of variance')   
plt.grid()
plt.show()

# %%
n= 30
latent_df = pd.DataFrame(latent_df[:, 0:n], index = df.Name.tolist())
latent_df
# Out:
#                                                      0         1         2   \
#  beyblade burst                                0.075166  0.047936  0.283540
#  fire emblem fates                             0.078367  0.051182  0.292976
#  frozen: olaf's quest                          0.266232  0.139021  0.406108
#  frozen: olaf's quest                          0.266232  0.139021  0.406108
#  haikyu!! cross team match!                    0.112197  0.050921  0.192309
# ...                                                 ...       ...       ...
# zumba fitness: world party                     0.273162  0.260885  0.736635
# zumba fitness: world party                     0.273162  0.260885  0.736635
# zwei!!                                         0.101514  0.128532  0.331667
# zyuden sentai kyoryuger: game de gaburincho!!  1.013568 -0.225878 -0.042465
# ¡shin chan flipa en colores!                   0.151340  0.107062  0.300064
#
#                                                      3         4         5   \
#  beyblade burst                               -0.647911  1.108117 -0.465803
#  fire emblem fates                            -0.661078  1.112202 -0.476389
#  frozen: olaf's quest                         -0.284332 -0.165218 -0.056505
#  frozen: olaf's quest                         -0.284332 -0.165218 -0.056505
#  haikyu!! cross team match!                   -0.204142  0.068136 -0.063753
# ...                                                 ...       ...       ...
# zumba fitness: world party                    -1.256737 -1.320567 -0.664755
# zumba fitness: world party                    -1.256737 -1.320567 -0.664755
# zwei!!                                        -0.662739  1.132189 -0.500790
# zyuden sentai kyoryuger: game de gaburincho!! -0.061971  0.081346 -0.110312
# ¡shin chan flipa en colores!                  -0.217262 -0.096776 -0.087803
#
#                                                      6         7         8   \
#  beyblade burst                               -0.068095 -0.128853 -0.075855
#  fire emblem fates                            -0.049387 -0.128894 -0.078770
#  frozen: olaf's quest                          1.854462  0.464924 -0.603359
#  frozen: olaf's quest                          1.854462  0.464924 -0.603359
#  haikyu!! cross team match!                    0.138017  0.721596  0.825245
# ...                                                 ...       ...       ...
# zumba fitness: world party                    -0.381283 -0.150754 -0.120344
# zumba fitness: world party                    -0.381283 -0.150754 -0.120344
# zwei!!                                        -0.031903 -0.126588  0.063817
# zyuden sentai kyoryuger: game de gaburincho!!  0.058146  0.051061  0.233718
# ¡shin chan flipa en colores!                   1.016623  0.279813 -0.114541
#
#                                                      9   ...        20  \
#  beyblade burst                               -0.069308  ...  0.093017
#  fire emblem fates                            -0.079149  ...  0.097025
#  frozen: olaf's quest                         -0.136989  ...  0.038580
#  frozen: olaf's quest                         -0.136989  ...  0.038580
#  haikyu!! cross team match!                   -0.154844  ...  0.203936
# ...                                                 ...  ...       ...
# zumba fitness: world party                    -0.094616  ...  0.318316
# zumba fitness: world party                    -0.094616  ...  0.318316
# zwei!!                                        -0.039981  ...  0.264052
# zyuden sentai kyoryuger: game de gaburincho!!  0.246446  ...  0.183803
# ¡shin chan flipa en colores!                   0.009170  ... -0.260755
#
#                                                      21        22        23  \
#  beyblade burst                               -0.010653  0.215754  0.068249
#  fire emblem fates                             0.026806  0.255131  0.195818
#  frozen: olaf's quest                         -0.058062  0.554025 -0.231462
#  frozen: olaf's quest                         -0.058062  0.554025 -0.231462
#  haikyu!! cross team match!                   -0.015960  0.110763  0.040772
# ...                                                 ...       ...       ...
# zumba fitness: world party                    -0.574232  0.010029  0.102573
# zumba fitness: world party                    -0.574232  0.010029  0.102573
# zwei!!                                         0.140093  0.125799  0.039667
# zyuden sentai kyoryuger: game de gaburincho!! -0.032989  0.107973  0.033232
# ¡shin chan flipa en colores!                  -0.073164 -0.092853 -0.268644
#
#                                                      24        25        26  \
#  beyblade burst                               -0.104773 -0.249692  0.546375
#  fire emblem fates                            -0.138590 -0.205142  0.746057
#  frozen: olaf's quest                         -0.159382 -0.271316  0.556323
#  frozen: olaf's quest                         -0.159382 -0.271316  0.556323
#  haikyu!! cross team match!                   -0.206246 -0.175325  0.572907
# ...                                                 ...       ...       ...
# zumba fitness: world party                    -0.285059  0.020193 -0.227305
# zumba fitness: world party                    -0.285059  0.020193 -0.227305
# zwei!!                                         0.022307 -0.040015 -0.037402
# zyuden sentai kyoryuger: game de gaburincho!! -0.178658 -0.154776  0.543580
# ¡shin chan flipa en colores!                   0.023402 -0.064462 -0.064085
#
#                                                      27        28        29
#  beyblade burst                                0.234628  0.314319  0.070818
#  fire emblem fates                             0.358497  0.466734  0.202825
#  frozen: olaf's quest                          0.056681  0.431419  0.355289
#  frozen: olaf's quest                          0.056681  0.431419  0.355289
#  haikyu!! cross team match!                    0.189714  0.389365 -0.130360
# ...                                                 ...       ...       ...
# zumba fitness: world party                    -0.293960  0.034464  0.088312
# zumba fitness: world party                    -0.293960  0.034464  0.088312
# zwei!!                                        -0.095069  0.015306  0.010395
# zyuden sentai kyoryuger: game de gaburincho!!  0.206326  0.367982 -0.113170
# ¡shin chan flipa en colores!                  -0.067110 -0.106961  0.318254
#
# [16716 rows x 30 columns]

# %% [markdown]
# ## Apply cosine similarity in contant

# %%
example = df['Name'][0]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Get the latent vectors fot example
v = np.array(latent_df.loc[example]).reshape(1, -1)

# Compute teh cosine similarity of this game
sim = cosine_similarity(latent_df, v).reshape(-1)

# %%
recommendation_df = pd.DataFrame({'content': sim}, index = latent_df.index)
recommendation_df
# Out:
#                                                 content
#  beyblade burst                                1.000000
#  fire emblem fates                             0.983136
#  frozen: olaf's quest                          0.160256
#  frozen: olaf's quest                          0.160256
#  haikyu!! cross team match!                    0.204315
# ...                                                 ...
# zumba fitness: world party                     0.005936
# zumba fitness: world party                     0.005936
# zwei!!                                         0.710988
# zyuden sentai kyoryuger: game de gaburincho!!  0.204560
# ¡shin chan flipa en colores!                  -0.029551
#
# [16716 rows x 1 columns]

# %%
recommendation_df.sort_values('content', ascending = False, inplace = True)
recommendation_df.head(10)
# Out:
#                                                      content
#  beyblade burst                                     1.000000
# the legend of legacy                                1.000000
# inazuma eleven go 2: chrono stone                   0.999996
# yokai watch 2 shinuchi                              0.999996
# girls rpg: cinderellife                             0.999996
# medabots 9: metabee / rokusho                       0.999978
# medabots dual: kabuto / kuwagata                    0.999978
# medabots girls mission: metabee ver. / rokusho ...  0.999978
# medarot 9: kabuto ver. / kuwagata ver.              0.999978
# medabots 8                                          0.999978

# %%
# recommendation_df = recommendation_df.reset_index()
top_5 = recommendation_df.merge(data, left_on='index', right_on = 'Name', how = 'left')[['index', 'content', 'Platform', 'Genre', 'Publisher']].head(5)

# %%
### top 5 similar to 

print(f"top 5 similar games to {example} are {top_5['index'].tolist()}")
# Out:
# top 5 similar games to  beyblade burst are [' beyblade burst', 'the legend of legacy', 'inazuma eleven go 2: chrono stone', 'yokai watch 2 shinuchi', 'girls rpg: cinderellife']
